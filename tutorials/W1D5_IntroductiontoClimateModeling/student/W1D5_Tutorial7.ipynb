# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiarsamosir/crisrisomas/blob/main/tutorials/W1D5_IntroductiontoClimateModeling/student/W1D5_Tutorial7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial 7: Introduction to CMIP6 Earth System Models
#
# **Week 1, Day 5, Introduction to Climate Modeling**
#
# **Content creators:** Julius Busecke, Robert Ford, Tom Nicholas, Brodie Pearson, and Brian E. J. Rose
#
# **Content reviewers:** Mujeeb Abdulfatai, Nkongho Ayuketang Arreyndip, Jeffrey N. A. Aryee, Younkap Nina Duplex, Sloane Garelick, Paul Heubel, Zahra Khodakaramimaghsoud, Peter Ohue, Jenna Pearson, Agustina Pesce, Abel Shibu, Derick Temfack, Peizhen Yang, Cheng Zhang, Chi Zhang, Ohad Zivan
#
# **Content editors:** Paul Heubel, Jenna Pearson, Ohad Zivan, Chi Zhang
#
# **Production editors:** Wesley Banfield, Paul Heubel, Jenna Pearson, Konstantine Tsafatinos, Chi Zhang, Ohad Zivan
#
# **Our 2024 Sponsors:** CMIP, NFDI4Earth

# %% [markdown]
# # Tutorial Objectives
#
# *Estimated timing of tutorial:* 30 minutes
#
# Earth System Models (ESMs) provide physically-based projections of how Earth's climate could change in the coming years, decades, and centuries at both global and local scales. In the following tutorial, you will:
#
# - Learn how to load, visualize, and manipulate ESM data from the [Coupled Model Intercomparison Project (CMIP6)](https://wcrp-cmip.org/cmip-phase-6-cmip6/)
# - Create maps showing projected future changes in sea surface temperature (SST)
# - Regrid SST data from a model-native grid to a regular latitude-longitude grid.

# %% [markdown]
# # Setup

# %%
# installations ( uncomment and run this cell ONLY when using google colab or kaggle )

# !wget -q https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
# !bash Miniforge3-Linux-x86_64.sh -b -p /opt/mf
# !/opt/mf/bin/mamba install -y -c conda-forge python=3.12 xesmf 'xarray==2024.2.0' xarray-datatree intake-esm gcsfs xmip aiohttp cartopy nc-time-axis cf_xarray xarrayutils

# !ln -sf /opt/mf/lib/libstdc++.so.6  /usr/lib/x86_64-linux-gnu/libstdc++.so.6
# !ln -sf /opt/mf/lib/libssl.so.3     /usr/lib/x86_64-linux-gnu/libssl.so.3
# !ln -sf /opt/mf/lib/libcrypto.so.3  /usr/lib/x86_64-linux-gnu/libcrypto.so.3
# Out:
# PREFIX=/opt/mf
# Unpacking bootstrapper...
# Unpacking payload...
# Extracting ca-certificates-2026.5.20-hbd8a1cb_0.conda
# Extracting libgomp-15.2.0-he0feb66_19.conda
# Extracting libzlib-1.3.2-h25fd6f3_2.conda
# Extracting nlohmann_json-abi-3.12.0-h0f90c79_1.conda
# Extracting pybind11-abi-11-hc364b38_1.conda
# Extracting python_abi-3.13-8_cp313.conda
# Extracting tzdata-2025c-hc9c84f9_1.conda
# Extracting _openmp_mutex-4.5-20_gnu.conda
# Extracting zstd-1.5.7-hb78ec9c_6.conda
# Extracting ld_impl_linux-64-2.45.1-default_hbd61a6d_102.conda
# Extracting libgcc-15.2.0-he0feb66_19.conda
# Extracting bzip2-1.0.8-hda65f42_9.conda
# Extracting c-ares-1.34.6-hb03c661_0.conda
# Extracting keyutils-1.6.3-hb9d3cd8_0.conda
# Extracting libexpat-2.8.1-hecca717_0.conda
# Extracting libffi-3.5.2-h3435931_0.conda
# Extracting libgcc-ng-15.2.0-h69a702a_19.conda
# Extracting libiconv-1.18-h3b78370_2.conda
# Extracting liblzma-5.8.3-hb03c661_0.conda
# Extracting libmpdec-4.0.0-hb03c661_1.conda
# Extracting libsqlite-3.53.1-h0c1763c_0.conda
# Extracting libstdcxx-15.2.0-h934c35e_19.conda
# Extracting libuuid-2.42.1-h5347b49_0.conda
# Extracting lzo-2.10-h280c20c_1002.conda
# Extracting ncurses-6.6-hdb14827_0.conda
# Extracting openssl-3.6.2-h35e630c_0.conda
# Extracting reproc-14.2.7.post0-hb03c661_1.conda
# Extracting tk-8.6.13-noxft_h366c992_103.conda
# Extracting cpp-expected-1.3.1-h171cf75_0.conda
# Extracting fmt-12.1.0-hff5e90c_0.conda
# Extracting icu-78.3-h33c6efd_0.conda
# Extracting libedit-3.1.20250104-pl5321h7949ede_0.conda
# Extracting libev-4.33-hd590300_2.conda
# Extracting libsolv-0.7.39-h9463b59_0.conda
# Extracting libssh2-1.11.1-hcf80075_0.conda
# Extracting lz4-c-1.10.0-h5888daf_1.conda
# Extracting readline-8.3-h853b02a_0.conda
# Extracting reproc-cpp-14.2.7.post0-hecca717_1.conda
# Extracting simdjson-4.2.4-hb700be7_0.conda
# Extracting yaml-cpp-0.8.0-h3f2d84a_0.conda
# Extracting krb5-1.22.2-ha1258a1_0.conda
# Extracting libnghttp2-1.68.1-h877daf1_0.conda
# Extracting libxml2-16-2.15.3-hca6bf5a_0.conda
# Extracting python-3.13.13-h6add32d_100_cp313.conda
# Extracting spdlog-1.17.0-hab81395_1.conda
# Extracting libcurl-8.20.0-hcf29cc6_0.conda
# Extracting libxml2-2.15.3-h49c6c72_0.conda
# Extracting menuinst-2.4.2-py313h78bf25f_0.conda
# Extracting archspec-0.2.5-pyhd8ed1ab_0.conda
# Extracting backports.zstd-1.5.0-py313h18e8e13_0.conda
# Extracting boltons-25.0.0-pyhd8ed1ab_0.conda
# Extracting brotli-python-1.2.0-py313hf159716_1.conda
# Extracting certifi-2026.5.20-pyhd8ed1ab_0.conda
# Extracting charset-normalizer-3.4.7-pyhd8ed1ab_0.conda
# Extracting distro-1.9.0-pyhd8ed1ab_1.conda
# Extracting frozendict-2.4.7-py313h07c4f96_0.conda
# Extracting hpack-4.1.0-pyhd8ed1ab_0.conda
# Extracting hyperframe-6.1.0-pyhd8ed1ab_0.conda
# Extracting idna-3.17-pyhcf101f3_0.conda
# Extracting jsonpointer-3.1.1-pyhcf101f3_0.conda
# Extracting libarchive-3.8.7-gpl_hc2c16d8_101.conda
# Extracting msgpack-python-1.1.2-py313h7037e92_1.conda
# Extracting packaging-26.2-pyhc364b38_0.conda
# Extracting pip-26.1.2-pyh145f28c_0.conda
# Extracting platformdirs-4.10.0-pyhcf101f3_0.conda
# Extracting pluggy-1.6.0-pyhf9edf01_1.conda
# Extracting pycosat-0.6.6-py313h07c4f96_3.conda
# Extracting pycparser-3.0-pyhcf101f3_0.conda
# Extracting pysocks-1.7.1-pyha55dd90_7.conda
# Extracting ruamel.yaml.clib-0.2.15-py313h54dd161_1.conda
# Extracting setuptools-82.0.1-pyh332efcf_0.conda
# Extracting tqdm-4.67.3-pyh8f84b5b_0.conda
# Extracting truststore-0.10.4-pyhcf101f3_0.conda
# Extracting cffi-2.0.0-py313hf46b229_1.conda
# Extracting h2-4.3.0-pyhcf101f3_0.conda
# Extracting jsonpatch-1.33-pyhd8ed1ab_1.conda
# Extracting libmamba-2.5.0-hd28c85e_0.conda
# Extracting ruamel.yaml-0.18.17-py313h54dd161_2.conda
# Extracting libmamba-spdlog-2.5.0-h12fcf84_0.conda
# Extracting mamba-2.5.0-h9835478_0.conda
# Extracting urllib3-2.7.0-pyhd8ed1ab_0.conda
# Extracting zstandard-0.25.0-py313h54dd161_1.conda
# Extracting conda-package-streaming-0.12.0-pyhd8ed1ab_0.conda
# Extracting libmambapy-2.5.0-py313h4616538_0.conda
# Extracting requests-2.34.2-pyhcf101f3_0.conda
# Extracting conda-libmamba-solver-26.4.2-pyhd8ed1ab_0.conda
# Extracting conda-package-handling-2.4.0-pyh7900ff3_2.conda
# Extracting conda-26.3.2-py313h78bf25f_1.conda
#
# Installing base environment...
#
# Transaction
#
#   Prefix: /opt/mf
#
#   Updating specs:
#
#    - ca-certificates==2026.5.20=hbd8a1cb_0
#    - libgomp==15.2.0=he0feb66_19
#    - libzlib==1.3.2=h25fd6f3_2
#    - nlohmann_json-abi==3.12.0=h0f90c79_1
#    - pybind11-abi==11=hc364b38_1
#    - python_abi==3.13=8_cp313
#    - tzdata==2025c=hc9c84f9_1
#    - _openmp_mutex==4.5=20_gnu
#    - zstd==1.5.7=hb78ec9c_6
#    - ld_impl_linux-64==2.45.1=default_hbd61a6d_102
#    - libgcc==15.2.0=he0feb66_19
#    - bzip2==1.0.8=hda65f42_9
#    - c-ares==1.34.6=hb03c661_0
#    - keyutils==1.6.3=hb9d3cd8_0
#    - libexpat==2.8.1=hecca717_0
#    - libffi==3.5.2=h3435931_0
#    - libgcc-ng==15.2.0=h69a702a_19
#    - libiconv==1.18=h3b78370_2
#    - liblzma==5.8.3=hb03c661_0
#    - libmpdec==4.0.0=hb03c661_1
#    - libsqlite==3.53.1=h0c1763c_0
#    - libstdcxx==15.2.0=h934c35e_19
#    - libuuid==2.42.1=h5347b49_0
#    - lzo==2.10=h280c20c_1002
#    - ncurses==6.6=hdb14827_0
#    - openssl==3.6.2=h35e630c_0
#    - reproc==14.2.7.post0=hb03c661_1
#    - tk==8.6.13=noxft_h366c992_103
#    - cpp-expected==1.3.1=h171cf75_0
#    - fmt==12.1.0=hff5e90c_0
#    - icu==78.3=h33c6efd_0
#    - libedit==3.1.20250104=pl5321h7949ede_0
#    - libev==4.33=hd590300_2
#    - libsolv==0.7.39=h9463b59_0
#    - libssh2==1.11.1=hcf80075_0
#    - lz4-c==1.10.0=h5888daf_1
#    - readline==8.3=h853b02a_0
#    - reproc-cpp==14.2.7.post0=hecca717_1
#    - simdjson==4.2.4=hb700be7_0
#    - yaml-cpp==0.8.0=h3f2d84a_0
#    - krb5==1.22.2=ha1258a1_0
#    - libnghttp2==1.68.1=h877daf1_0
#    - libxml2-16==2.15.3=hca6bf5a_0
#    - python==3.13.13=h6add32d_100_cp313
#    - spdlog==1.17.0=hab81395_1
#    - libcurl==8.20.0=hcf29cc6_0
#    - libxml2==2.15.3=h49c6c72_0
#    - menuinst==2.4.2=py313h78bf25f_0
#    - archspec==0.2.5=pyhd8ed1ab_0
#    - backports.zstd==1.5.0=py313h18e8e13_0
#    - boltons==25.0.0=pyhd8ed1ab_0
#    - brotli-python==1.2.0=py313hf159716_1
#    - certifi==2026.5.20=pyhd8ed1ab_0
#    - charset-normalizer==3.4.7=pyhd8ed1ab_0
#    - distro==1.9.0=pyhd8ed1ab_1
#    - frozendict==2.4.7=py313h07c4f96_0
#    - hpack==4.1.0=pyhd8ed1ab_0
#    - hyperframe==6.1.0=pyhd8ed1ab_0
#    - idna==3.17=pyhcf101f3_0
#    - jsonpointer==3.1.1=pyhcf101f3_0
#    - libarchive==3.8.7=gpl_hc2c16d8_101
#    - msgpack-python==1.1.2=py313h7037e92_1
#    - packaging==26.2=pyhc364b38_0
#    - pip==26.1.2=pyh145f28c_0
#    - platformdirs==4.10.0=pyhcf101f3_0
#    - pluggy==1.6.0=pyhf9edf01_1
#    - pycosat==0.6.6=py313h07c4f96_3
#    - pycparser==3.0=pyhcf101f3_0
#    - pysocks==1.7.1=pyha55dd90_7
#    - ruamel.yaml.clib==0.2.15=py313h54dd161_1
#    - setuptools==82.0.1=pyh332efcf_0
#    - tqdm==4.67.3=pyh8f84b5b_0
#    - truststore==0.10.4=pyhcf101f3_0
#    - cffi==2.0.0=py313hf46b229_1
#    - h2==4.3.0=pyhcf101f3_0
#    - jsonpatch==1.33=pyhd8ed1ab_1
#    - libmamba==2.5.0=hd28c85e_0
#    - ruamel.yaml==0.18.17=py313h54dd161_2
#    - libmamba-spdlog==2.5.0=h12fcf84_0
#    - mamba==2.5.0=h9835478_0
#    - urllib3==2.7.0=pyhd8ed1ab_0
#    - zstandard==0.25.0=py313h54dd161_1
#    - conda-package-streaming==0.12.0=pyhd8ed1ab_0
#    - libmambapy==2.5.0=py313h4616538_0
#    - requests==2.34.2=pyhcf101f3_0
#    - conda-libmamba-solver==26.4.2=pyhd8ed1ab_0
#    - conda-package-handling==2.4.0=pyh7900ff3_2
#    - conda==26.3.2=py313h78bf25f_1
#
#
#   Package                         Version  Build                 Channel         Size
# ───────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────
#
#   + _openmp_mutex                     4.5  20_gnu                conda-forge
#   + archspec                        0.2.5  pyhd8ed1ab_0          conda-forge
#   + backports.zstd                  1.5.0  py313h18e8e13_0       conda-forge
#   + boltons                        25.0.0  pyhd8ed1ab_0          conda-forge
#   + brotli-python                   1.2.0  py313hf159716_1       conda-forge
#   + bzip2                           1.0.8  hda65f42_9            conda-forge
#   + c-ares                         1.34.6  hb03c661_0            conda-forge
#   + ca-certificates             2026.5.20  hbd8a1cb_0            conda-forge
#   + certifi                     2026.5.20  pyhd8ed1ab_0          conda-forge
#   + cffi                            2.0.0  py313hf46b229_1       conda-forge
#   + charset-normalizer              3.4.7  pyhd8ed1ab_0          conda-forge
#   + conda                          26.3.2  py313h78bf25f_1       conda-forge
#   + conda-libmamba-solver          26.4.2  pyhd8ed1ab_0          conda-forge
#   + conda-package-handling          2.4.0  pyh7900ff3_2          conda-forge
#   + conda-package-streaming        0.12.0  pyhd8ed1ab_0          conda-forge
#   + cpp-expected                    1.3.1  h171cf75_0            conda-forge
#   + distro                          1.9.0  pyhd8ed1ab_1          conda-forge
#   + fmt                            12.1.0  hff5e90c_0            conda-forge
#   + frozendict                      2.4.7  py313h07c4f96_0       conda-forge
#   + h2                              4.3.0  pyhcf101f3_0          conda-forge
#   + hpack                           4.1.0  pyhd8ed1ab_0          conda-forge
#   + hyperframe                      6.1.0  pyhd8ed1ab_0          conda-forge
#   + icu                              78.3  h33c6efd_0            conda-forge
#   + idna                             3.17  pyhcf101f3_0          conda-forge
#   + jsonpatch                        1.33  pyhd8ed1ab_1          conda-forge
#   + jsonpointer                     3.1.1  pyhcf101f3_0          conda-forge
#   + keyutils                        1.6.3  hb9d3cd8_0            conda-forge
#   + krb5                           1.22.2  ha1258a1_0            conda-forge
#   + ld_impl_linux-64               2.45.1  default_hbd61a6d_102  conda-forge
#   + libarchive                      3.8.7  gpl_hc2c16d8_101      conda-forge
#   + libcurl                        8.20.0  hcf29cc6_0            conda-forge
#   + libedit                  3.1.20250104  pl5321h7949ede_0      conda-forge
#   + libev                            4.33  hd590300_2            conda-forge
#   + libexpat                        2.8.1  hecca717_0            conda-forge
#   + libffi                          3.5.2  h3435931_0            conda-forge
#   + libgcc                         15.2.0  he0feb66_19           conda-forge
#   + libgcc-ng                      15.2.0  h69a702a_19           conda-forge
#   + libgomp                        15.2.0  he0feb66_19           conda-forge
#   + libiconv                         1.18  h3b78370_2            conda-forge
#   + liblzma                         5.8.3  hb03c661_0            conda-forge
#   + libmamba                        2.5.0  hd28c85e_0            conda-forge
#   + libmamba-spdlog                 2.5.0  h12fcf84_0            conda-forge
#   + libmambapy                      2.5.0  py313h4616538_0       conda-forge
#   + libmpdec                        4.0.0  hb03c661_1            conda-forge
#   + libnghttp2                     1.68.1  h877daf1_0            conda-forge
#   + libsolv                        0.7.39  h9463b59_0            conda-forge
#   + libsqlite                      3.53.1  h0c1763c_0            conda-forge
#   + libssh2                        1.11.1  hcf80075_0            conda-forge
#   + libstdcxx                      15.2.0  h934c35e_19           conda-forge
#   + libuuid                        2.42.1  h5347b49_0            conda-forge
#   + libxml2                        2.15.3  h49c6c72_0            conda-forge
#   + libxml2-16                     2.15.3  hca6bf5a_0            conda-forge
#   + libzlib                         1.3.2  h25fd6f3_2            conda-forge
#   + lz4-c                          1.10.0  h5888daf_1            conda-forge
#   + lzo                              2.10  h280c20c_1002         conda-forge
#   + mamba                           2.5.0  h9835478_0            conda-forge
#   + menuinst                        2.4.2  py313h78bf25f_0       conda-forge
#   + msgpack-python                  1.1.2  py313h7037e92_1       conda-forge
#   + ncurses                           6.6  hdb14827_0            conda-forge
#   + nlohmann_json-abi              3.12.0  h0f90c79_1            conda-forge
#   + openssl                         3.6.2  h35e630c_0            conda-forge
#   + packaging                        26.2  pyhc364b38_0          conda-forge
#   + pip                            26.1.2  pyh145f28c_0          conda-forge
#   + platformdirs                   4.10.0  pyhcf101f3_0          conda-forge
#   + pluggy                          1.6.0  pyhf9edf01_1          conda-forge
#   + pybind11-abi                       11  hc364b38_1            conda-forge
#   + pycosat                         0.6.6  py313h07c4f96_3       conda-forge
#   + pycparser                         3.0  pyhcf101f3_0          conda-forge
#   + pysocks                         1.7.1  pyha55dd90_7          conda-forge
#   + python                        3.13.13  h6add32d_100_cp313    conda-forge
#   + python_abi                       3.13  8_cp313               conda-forge
#   + readline                          8.3  h853b02a_0            conda-forge
#   + reproc                   14.2.7.post0  hb03c661_1            conda-forge
#   + reproc-cpp               14.2.7.post0  hecca717_1            conda-forge
#   + requests                       2.34.2  pyhcf101f3_0          conda-forge
#   + ruamel.yaml                   0.18.17  py313h54dd161_2       conda-forge
#   + ruamel.yaml.clib               0.2.15  py313h54dd161_1       conda-forge
#   + setuptools                     82.0.1  pyh332efcf_0          conda-forge
#   + simdjson                        4.2.4  hb700be7_0            conda-forge
#   + spdlog                         1.17.0  hab81395_1            conda-forge
#   + tk                             8.6.13  noxft_h366c992_103    conda-forge
#   + tqdm                           4.67.3  pyh8f84b5b_0          conda-forge
#   + truststore                     0.10.4  pyhcf101f3_0          conda-forge
#   + tzdata                          2025c  hc9c84f9_1            conda-forge
#   + urllib3                         2.7.0  pyhd8ed1ab_0          conda-forge
#   + yaml-cpp                        0.8.0  h3f2d84a_0            conda-forge
#   + zstandard                      0.25.0  py313h54dd161_1       conda-forge
#   + zstd                            1.5.7  hb78ec9c_6            conda-forge
#
#   Summary:
#
#   Install: 88 packages
#
#   Total download: 0 B
#
# ───────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking ca-certificates-2026.5.20-hbd8a1cb_0
# Linking libgomp-15.2.0-he0feb66_19
# Linking libzlib-1.3.2-h25fd6f3_2
# Linking nlohmann_json-abi-3.12.0-h0f90c79_1
# Linking pybind11-abi-11-hc364b38_1
# Linking python_abi-3.13-8_cp313
# Linking tzdata-2025c-hc9c84f9_1
# Linking _openmp_mutex-4.5-20_gnu
# Linking zstd-1.5.7-hb78ec9c_6
# Linking ld_impl_linux-64-2.45.1-default_hbd61a6d_102
# Linking libgcc-15.2.0-he0feb66_19
# Linking bzip2-1.0.8-hda65f42_9
# Linking c-ares-1.34.6-hb03c661_0
# Linking keyutils-1.6.3-hb9d3cd8_0
# Linking libexpat-2.8.1-hecca717_0
# Linking libffi-3.5.2-h3435931_0
# Linking libgcc-ng-15.2.0-h69a702a_19
# Linking libiconv-1.18-h3b78370_2
# Linking liblzma-5.8.3-hb03c661_0
# Linking libmpdec-4.0.0-hb03c661_1
# Linking libsqlite-3.53.1-h0c1763c_0
# Linking libstdcxx-15.2.0-h934c35e_19
# Linking libuuid-2.42.1-h5347b49_0
# Linking lzo-2.10-h280c20c_1002
# Linking ncurses-6.6-hdb14827_0
# Linking openssl-3.6.2-h35e630c_0
# Linking reproc-14.2.7.post0-hb03c661_1
# Linking tk-8.6.13-noxft_h366c992_103
# Linking cpp-expected-1.3.1-h171cf75_0
# Linking fmt-12.1.0-hff5e90c_0
# Linking icu-78.3-h33c6efd_0
# Linking libedit-3.1.20250104-pl5321h7949ede_0
# Linking libev-4.33-hd590300_2
# Linking libsolv-0.7.39-h9463b59_0
# Linking libssh2-1.11.1-hcf80075_0
# Linking lz4-c-1.10.0-h5888daf_1
# Linking readline-8.3-h853b02a_0
# Linking reproc-cpp-14.2.7.post0-hecca717_1
# Linking simdjson-4.2.4-hb700be7_0
# Linking yaml-cpp-0.8.0-h3f2d84a_0
# Linking krb5-1.22.2-ha1258a1_0
# Linking libnghttp2-1.68.1-h877daf1_0
# Linking libxml2-16-2.15.3-hca6bf5a_0
# Linking python-3.13.13-h6add32d_100_cp313
# Linking spdlog-1.17.0-hab81395_1
# Linking libcurl-8.20.0-hcf29cc6_0
# Linking libxml2-2.15.3-h49c6c72_0
# Linking menuinst-2.4.2-py313h78bf25f_0
# Linking archspec-0.2.5-pyhd8ed1ab_0
# Linking backports.zstd-1.5.0-py313h18e8e13_0
# Linking boltons-25.0.0-pyhd8ed1ab_0
# Linking brotli-python-1.2.0-py313hf159716_1
# Linking certifi-2026.5.20-pyhd8ed1ab_0
# Linking charset-normalizer-3.4.7-pyhd8ed1ab_0
# Linking distro-1.9.0-pyhd8ed1ab_1
# Linking frozendict-2.4.7-py313h07c4f96_0
# Linking hpack-4.1.0-pyhd8ed1ab_0
# Linking hyperframe-6.1.0-pyhd8ed1ab_0
# Linking idna-3.17-pyhcf101f3_0
# Linking jsonpointer-3.1.1-pyhcf101f3_0
# Linking libarchive-3.8.7-gpl_hc2c16d8_101
# Linking msgpack-python-1.1.2-py313h7037e92_1
# Linking packaging-26.2-pyhc364b38_0
# Linking pip-26.1.2-pyh145f28c_0
# Linking platformdirs-4.10.0-pyhcf101f3_0
# Linking pluggy-1.6.0-pyhf9edf01_1
# Linking pycosat-0.6.6-py313h07c4f96_3
# Linking pycparser-3.0-pyhcf101f3_0
# Linking pysocks-1.7.1-pyha55dd90_7
# Linking ruamel.yaml.clib-0.2.15-py313h54dd161_1
# Linking setuptools-82.0.1-pyh332efcf_0
# Linking tqdm-4.67.3-pyh8f84b5b_0
# Linking truststore-0.10.4-pyhcf101f3_0
# Linking cffi-2.0.0-py313hf46b229_1
# Linking h2-4.3.0-pyhcf101f3_0
# Linking jsonpatch-1.33-pyhd8ed1ab_1
# Linking libmamba-2.5.0-hd28c85e_0
# Linking ruamel.yaml-0.18.17-py313h54dd161_2
# Linking libmamba-spdlog-2.5.0-h12fcf84_0
# Linking mamba-2.5.0-h9835478_0
# Linking urllib3-2.7.0-pyhd8ed1ab_0
# Linking zstandard-0.25.0-py313h54dd161_1
# Linking conda-package-streaming-0.12.0-pyhd8ed1ab_0
# Linking libmambapy-2.5.0-py313h4616538_0
# Linking requests-2.34.2-pyhcf101f3_0
# Linking conda-libmamba-solver-26.4.2-pyhd8ed1ab_0
# Linking conda-package-handling-2.4.0-pyh7900ff3_2
# Linking conda-26.3.2-py313h78bf25f_1
#
# Transaction finished
#
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniforge3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniforge3: /opt/mf
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   2%
# conda-forge/noarch     5%[+] 0.3s
# conda-forge/linux-64   8%
# conda-forge/noarch    18%[+] 0.4s
# conda-forge/linux-64  14%
# conda-forge/noarch    28%[+] 0.5s
# conda-forge/linux-64  20%
# conda-forge/noarch    40%[+] 0.6s
# conda-forge/linux-64  25%
# conda-forge/noarch    52%[+] 0.7s
# conda-forge/linux-64  32%
# conda-forge/noarch    66%[+] 0.8s
# conda-forge/linux-64  34%
# conda-forge/noarch    70%[+] 0.9s
# conda-forge/linux-64  37%
# conda-forge/noarch    76%[+] 1.0s
# conda-forge/linux-64  37%
# conda-forge/noarch    76%[+] 1.1s
# conda-forge/linux-64  37%
# conda-forge/noarch    76%[+] 1.2s
# conda-forge/linux-64  37%
# conda-forge/noarch    76%[+] 1.3s
# conda-forge/linux-64  37%
# conda-forge/noarch    76%[+] 1.4s
# conda-forge/linux-64  37%
# conda-forge/noarch    76%[+] 1.5s
# conda-forge/linux-64  39%
# conda-forge/noarch    76%[+] 1.6s
# conda-forge/linux-64  39%
# conda-forge/noarch    76%[+] 1.7s
# conda-forge/linux-64  39%
# conda-forge/noarch    76%[+] 1.8s
# conda-forge/linux-64  39%
# conda-forge/noarch    76%[+] 1.9s
# conda-forge/linux-64  39%
# conda-forge/noarch    76%[+] 2.0s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.1s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.2s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.3s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.4s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.5s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.6s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.7s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.8s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 2.9s
# conda-forge/linux-64  39%
# conda-forge/noarch    79%[+] 3.0s
# conda-forge/linux-64  44%
# conda-forge/noarch    89%conda-forge/noarch
# [+] 3.1s
# conda-forge/linux-64  51%[+] 3.2s
# conda-forge/linux-64  61%[+] 3.3s
# conda-forge/linux-64  65%[+] 3.4s
# conda-forge/linux-64  73%[+] 3.5s
# conda-forge/linux-64  83%[+] 3.6s
# conda-forge/linux-64  93%conda-forge/linux-64
#
#
# Transaction
#
#   Prefix: /opt/mf
#
#   Updating specs:
#
#    - python=3.12
#    - xesmf
#    - xarray==2024.2.0
#    - xarray-datatree
#    - intake-esm
#    - gcsfs
#    - xmip
#    - aiohttp
#    - cartopy
#    - nc-time-axis
#    - cf_xarray
#    - xarrayutils
#
#
#   Package                                        Version  Build                    Channel           Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _python_abi3_support                             1.0  hd8ed1ab_3               conda-forge        8kB
#   + aiobotocore                                    3.7.0  pyhcf101f3_0             conda-forge       84kB
#   + aiohappyeyeballs                               2.7.1  pyhd8ed1ab_0             conda-forge       25kB
#   + aiohttp                                       3.14.1  py312h5d8c7f2_0          conda-forge        1MB
#   + aioitertools                                  0.13.0  pyhd8ed1ab_0             conda-forge       25kB
#   + aiosignal                                      1.4.0  pyhd8ed1ab_0             conda-forge       14kB
#   + annotated-types                                0.7.0  pyhd8ed1ab_1             conda-forge       18kB
#   + anyio                                         4.14.2  pyhcf101f3_0             conda-forge      164kB
#   + appdirs                                        1.4.4  pyhd8ed1ab_1             conda-forge       15kB
#   + apsw                                        3.53.1.0  py312h4c3975b_0          conda-forge        1MB
#   + apswutils                                      0.1.2  pyhcf101f3_0             conda-forge       53kB
#   + astropy                                        7.2.0  pyhd8ed1ab_0             conda-forge        9kB
#   + astropy-base                                   7.2.0  py312h4f23490_0          conda-forge       10MB
#   + astropy-iers-data                 0.2026.7.13.0.54.2  pyhd8ed1ab_0             conda-forge        1MB
#   + asttokens                                      3.0.2  pyhd8ed1ab_0             conda-forge       35kB
#   + attrs                                         26.1.0  pyhcf101f3_0             conda-forge       65kB
#   + aws-c-auth                                    0.10.3  hd2277e8_3               conda-forge      135kB
#   + aws-c-cal                                     0.9.14  h78948cc_2               conda-forge       57kB
#   + aws-c-common                                  0.14.0  hb03c661_0               conda-forge      242kB
#   + aws-c-compression                              0.3.2  haa0cbde_2               conda-forge       22kB
#   + aws-c-event-stream                             0.7.1  h9cf6be0_2               conda-forge       59kB
#   + aws-c-http                                    0.11.0  h6488f85_2               conda-forge      230kB
#   + aws-c-io                                      0.26.3  h3bf836e_5               conda-forge      182kB
#   + aws-c-mqtt                                    0.16.0  h0d2f46f_0               conda-forge      224kB
#   + aws-c-s3                                      0.12.6  hb916526_0               conda-forge      154kB
#   + aws-c-sdkutils                                 0.2.5  haa0cbde_0               conda-forge       66kB
#   + aws-checksums                                 0.2.10  haa0cbde_2               conda-forge      102kB
#   + aws-crt-cpp                                   0.40.1  h7a9a9d6_1               conda-forge      416kB
#   + aws-sdk-cpp                                 1.11.833  hf4c7647_7               conda-forge        3MB
#   + azure-core-cpp                                1.16.3  h206d751_0               conda-forge      349kB
#   + azure-identity-cpp                            1.13.3  h71f81a8_2               conda-forge      251kB
#   + azure-storage-blobs-cpp                      12.18.0  h74b55db_1               conda-forge      590kB
#   + azure-storage-common-cpp                     12.14.0  hf596fc9_1               conda-forge      159kB
#   + azure-storage-files-datalake-cpp             12.16.0  h1f05bef_1               conda-forge      309kB
#   + beautifulsoup4                                4.15.0  pyha770c72_0             conda-forge       93kB
#   + bleach                                         6.4.0  pyhcf101f3_0             conda-forge      142kB
#   + blinker                                        1.9.0  pyhff2d567_0             conda-forge       14kB
#   + blosc                                         1.21.6  he440d0b_1               conda-forge       48kB
#   + bokeh                                          3.9.1  pyhd8ed1ab_0             conda-forge        5MB
#   + botocore                                      1.43.0  pyhd8ed1ab_0             conda-forge        9MB
#   + bottleneck                                     1.6.0  np2py312hfb8c2c5_3       conda-forge      158kB
#   + bqplot                                        0.13.1  pyhcf101f3_0             conda-forge      785kB
#   + bqscales                                       0.3.7  pyhd8ed1ab_1             conda-forge      216kB
#   + brotli                                         1.2.0  hed03a55_1               conda-forge       20kB
#   + brotli-bin                                     1.2.0  hb03c661_1               conda-forge       21kB
#   + cached-property                                1.5.2  hd8ed1ab_2               conda-forge        7kB
#   + cached_property                                1.5.2  pyha770c72_2             conda-forge       15kB
#   + cairo                                         1.18.4  he90730b_1               conda-forge      990kB
#   + cartopy                                       0.25.0  py312hf79963d_1          conda-forge        2MB
#   + cf-xarray                                    0.10.11  pyhd8ed1ab_1             conda-forge       11kB
#   + cf_xarray                                    0.10.11  pyhd8ed1ab_0             conda-forge       70kB
#   + cftime                                         1.6.5  py312h4f23490_1          conda-forge      427kB
#   + click                                          8.4.2  pyhc90fa1f_0             conda-forge      107kB
#   + cloudpickle                                    3.1.2  pyhcf101f3_1             conda-forge       27kB
#   + colorama                                       0.4.6  pyhd8ed1ab_1             conda-forge       27kB
#   + comm                                           0.2.3  pyhe01879c_0             conda-forge       15kB
#   + conda-index                                   0.12.1  pyhd8ed1ab_0             conda-forge      211kB
#   + conda-lockfiles                                0.2.1  pyhd8ed1ab_0             conda-forge       21kB
#   + conda-pypi                                    0.11.0  py312h20c3967_1          conda-forge      319kB
#   + conda-rattler-solver                           0.1.1  pyhcf101f3_0             conda-forge       37kB
#   + conda-self                                     0.2.0  pyhd8ed1ab_0             conda-forge       22kB
#   + contourpy                                      1.3.3  py312h0a2e395_4          conda-forge      320kB
#   + cpython                                      3.12.13  py312hd8ed1ab_0          conda-forge       46kB
#   + cryptography                                  49.0.0  py312ha4b625e_0          conda-forge        2MB
#   + cycler                                        0.12.1  pyhcf101f3_2             conda-forge       15kB
#   + cytoolz                                        1.1.0  py312h4c3975b_2          conda-forge      624kB
#   + dask                                        2026.7.1  pyhc364b38_0             conda-forge       10kB
#   + dask-core                                   2026.7.1  pyhc364b38_0             conda-forge        1MB
#   + debugpy                                       1.8.21  py312h8285ef7_0          conda-forge        3MB
#   + decorator                                      5.3.1  pyhd8ed1ab_0             conda-forge       16kB
#   + deprecated                                     1.3.1  pyhd8ed1ab_1             conda-forge       16kB
#   + distributed                                 2026.7.1  pyhc364b38_0             conda-forge      843kB
#   + donfig                                   0.8.1.post1  pyhd8ed1ab_1             conda-forge       22kB
#   + entrypoints                                      0.4  pyhd8ed1ab_1             conda-forge       11kB
#   + esmf                                           8.9.1  mpi_mpich_ha43e4ac_103   conda-forge       27MB
#   + esmpy                                          8.9.1  pyhdfbf58e_0             conda-forge        2MB
#   + exceptiongroup                                 1.3.1  pyhd8ed1ab_0             conda-forge       21kB
#   + executing                                      2.2.1  pyhd8ed1ab_0             conda-forge       31kB
#   + fastcore                                       2.1.1  pyhc364b38_0             conda-forge      107kB
#   + fastlite                                       0.2.3  pyhcf101f3_0             conda-forge       27kB
#   + fastprogress                                   1.1.6  pyhd8ed1ab_0             conda-forge       20kB
#   + filelock                                      3.30.2  pyhd8ed1ab_0             conda-forge       74kB
#   + flexcache                                        0.3  pyhd8ed1ab_1             conda-forge       17kB
#   + flexparser                                       0.4  pyhd8ed1ab_1             conda-forge       29kB
#   + font-ttf-dejavu-sans-mono                       2.37  hab24e00_0               conda-forge      397kB
#   + font-ttf-inconsolata                           3.000  h77eed37_0               conda-forge       97kB
#   + font-ttf-source-code-pro                       2.038  h77eed37_0               conda-forge      701kB
#   + font-ttf-ubuntu                                 0.83  h77eed37_3               conda-forge        2MB
#   + fontconfig                                    2.18.1  h27c8c51_0               conda-forge      282kB
#   + fonts-conda-ecosystem                              1  0                        conda-forge        4kB
#   + fonts-conda-forge                                  1  hc364b38_1               conda-forge        4kB
#   + fonttools                                     4.63.0  py312h8a5da7c_0          conda-forge        3MB
#   + freetype                                      2.14.3  ha770c72_0               conda-forge      174kB
#   + fribidi                                       1.0.16  hb03c661_0               conda-forge       61kB
#   + frozenlist                                     1.8.0  py312h447239a_0          conda-forge       55kB
#   + fsspec                                      2026.6.0  pyhd8ed1ab_0             conda-forge      150kB
#   + gast                                           0.7.0  pyhd8ed1ab_0             conda-forge       27kB
#   + gcsfs                                       2026.7.0  pyhd8ed1ab_0             conda-forge       81kB
#   + geos                                          3.14.1  h480dda7_0               conda-forge        2MB
#   + gflags                                         2.3.0  h54a6638_0               conda-forge      131kB
#   + glog                                           0.7.1  hb7133d2_1               conda-forge      149kB
#   + google-api-core                               2.31.0  pyhcf101f3_0             conda-forge      105kB
#   + google-auth                                   2.56.0  pyhcf101f3_0             conda-forge      155kB
#   + google-auth-oauthlib                           1.4.0  pyhd8ed1ab_0             conda-forge       23kB
#   + google-cloud-core                              2.6.0  pyhcf101f3_1             conda-forge       33kB
#   + google-cloud-storage                          3.13.0  pyhcf101f3_0             conda-forge      213kB
#   + google-cloud-storage-control                  1.10.0  pyhcf101f3_0             conda-forge       62kB
#   + google-crc32c                                  1.8.0  py312h03f33d3_1          conda-forge       25kB
#   + google-resumable-media                         2.8.0  pyhd8ed1ab_0             conda-forge       47kB
#   + googleapis-common-protos                      1.75.0  pyhcf101f3_0             conda-forge      150kB
#   + googleapis-common-protos-grpc                 1.75.0  pyhcf101f3_0             conda-forge       12kB
#   + graphite2                                     1.3.15  hecca717_0               conda-forge      100kB
#   + grpc-google-iam-v1                            0.14.4  pyhcf101f3_0             conda-forge       31kB
#   + grpcio                                        1.78.1  py312h39ee1c6_0          conda-forge      876kB
#   + grpcio-status                                 1.78.1  pyhcf101f3_0             conda-forge       28kB
#   + h11                                           0.16.0  pyhcf101f3_1             conda-forge       39kB
#   + h5py                                          3.16.0  nompi_py312ha829cd9_102  conda-forge        1MB
#   + hdf4                                          4.2.15  h2a13503_7               conda-forge      757kB
#   + hdf5                                           2.1.0  mpi_mpich_h1816c52_8     conda-forge        4MB
#   + html5lib                                         1.1  pyhd8ed1ab_2             conda-forge       95kB
#   + httpcore                                       1.0.9  pyh29332c3_0             conda-forge       49kB
#   + httpcore2                                      2.3.0  pyhcf101f3_0             conda-forge       52kB
#   + httpx                                         0.28.1  pyhd8ed1ab_0             conda-forge       63kB
#   + httpx2                                         2.3.0  pyhcf101f3_0             conda-forge       71kB
#   + importlib-metadata                             9.0.0  pyhcf101f3_0             conda-forge       35kB
#   + intake                                         0.7.0  pyhd8ed1ab_0             conda-forge      193kB
#   + intake-esm                                  2024.2.6  pyhd8ed1ab_2             conda-forge       31kB
#   + ipydatagrid                                    1.4.0  pyhcf101f3_2             conda-forge      681kB
#   + ipykernel                                      7.3.0  pyha191276_0             conda-forge      139kB
#   + ipython                                       9.15.0  pyh53cf698_0             conda-forge      659kB
#   + ipython_pygments_lexers                        1.1.1  pyhd8ed1ab_0             conda-forge       14kB
#   + ipywidgets                                     8.1.8  pyhd8ed1ab_0             conda-forge      114kB
#   + itsdangerous                                   2.2.0  pyhd8ed1ab_1             conda-forge       19kB
#   + jedi                                          0.20.0  pyhcf101f3_0             conda-forge        3MB
#   + jinja2                                         3.1.6  pyhcf101f3_1             conda-forge      121kB
#   + jmespath                                       1.1.0  pyhcf101f3_1             conda-forge       26kB
#   + jplephem                                        2.24  pyha4b2019_1             conda-forge       42kB
#   + jupyter_client                                 8.9.1  pyhcf101f3_0             conda-forge      118kB
#   + jupyter_core                                   5.9.1  pyhc90fa1f_0             conda-forge       66kB
#   + jupyterlab_widgets                            3.0.16  pyhcf101f3_1             conda-forge      217kB
#   + kiwisolver                                     1.5.0  py312h0a2e395_0          conda-forge       77kB
#   + lcms2                                         2.19.1  h0c24ade_1               conda-forge      252kB
#   + lerc                                           4.1.0  hdb68285_0               conda-forge      262kB
#   + libabseil                                 20260107.1  cxx17_h7b12aa8_0         conda-forge        1MB
#   + libaec                                         1.1.5  h088129d_0               conda-forge       37kB
#   + libarrow                                      24.0.0  h3e48024_9_cpu           conda-forge        7MB
#   + libarrow-acero                                24.0.0  h635bf11_9_cpu           conda-forge      591kB
#   + libarrow-compute                              24.0.0  h53684a4_9_cpu           conda-forge        3MB
#   + libarrow-dataset                              24.0.0  h635bf11_9_cpu           conda-forge      591kB
#   + libarrow-substrait                            24.0.0  hb4dd7c2_9_cpu           conda-forge      501kB
#   + libblas                                       3.11.0  8_h4a7cf45_openblas      conda-forge       19kB
#   + libbrotlicommon                                1.2.0  hb03c661_1               conda-forge       80kB
#   + libbrotlidec                                   1.2.0  hb03c661_1               conda-forge       35kB
#   + libbrotlienc                                   1.2.0  hb03c661_1               conda-forge      298kB
#   + libcap                                          2.78  hd0affe5_0               conda-forge      124kB
#   + libcblas                                      3.11.0  8_h0358290_openblas      conda-forge       19kB
#   + libcrc32c                                      1.1.2  h9c3ff4c_0               conda-forge       20kB
#   + libdeflate                                      1.25  h17f619e_0               conda-forge       73kB
#   + libevent                                      2.1.12  hf998b51_1               conda-forge      427kB
#   + libfabric                                      2.6.0  ha770c72_0               conda-forge       14kB
#   + libfabric1                                     2.6.0  h6b3ec72_0               conda-forge      735kB
#   + libfreetype                                   2.14.3  ha770c72_0               conda-forge        8kB
#   + libfreetype6                                  2.14.3  h73754d4_0               conda-forge      385kB
#   + libgfortran                                   15.2.0  h69a702a_19              conda-forge       28kB
#   + libgfortran5                                  15.2.0  h68bc16d_19              conda-forge        2MB
#   + libglib                                       2.88.2  h0d30a3d_0               conda-forge        5MB
#   + libgoogle-cloud                                3.6.0  h8d2ee43_0               conda-forge        3MB
#   + libgoogle-cloud-storage                        3.6.0  hdbdcf42_0               conda-forge      786kB
#   + libgrpc                                       1.78.1  h1d1128b_0               conda-forge        7MB
#   + libharfbuzz                                   14.2.1  h17a8019_1               conda-forge        1MB
#   + libhwloc                                      2.13.0  default_he001693_1000    conda-forge        2MB
#   + libjpeg-turbo                                  3.2.0  hb03c661_0               conda-forge      653kB
#   + liblapack                                     3.11.0  8_h47877c9_openblas      conda-forge       19kB
#   + libnetcdf                                     4.10.0  mpi_mpich_h65e3e28_4     conda-forge      872kB
#   + libnl                                         3.11.0  hb9d3cd8_0               conda-forge      741kB
#   + libnsl                                         2.0.1  hb9d3cd8_1               conda-forge       34kB
#   + libopenblas                                   0.3.33  pthreads_h94d23a6_0      conda-forge        6MB
#   + libopentelemetry-cpp                          1.27.0  h9692893_0               conda-forge      943kB
#   + libopentelemetry-cpp-headers                  1.27.0  ha770c72_0               conda-forge      392kB
#   + libparquet                                    24.0.0  h7376487_9_cpu           conda-forge        1MB
#   + libpnetcdf                                    1.14.1  mpi_mpich_h0009a5c_101   conda-forge        2MB
#   + libpng                                        1.6.58  h421ea60_0               conda-forge      318kB
#   + libprotobuf                                   6.33.5  h538a264_2               conda-forge        4MB
#   + libraqm                                       0.10.5  h6406941_1               conda-forge       29kB
#   + libre2-11                                 2025.11.05  h0dc7533_1               conda-forge      213kB
#   + libsodium                                     1.0.22  h280c20c_1               conda-forge      269kB
#   + libstdcxx-ng                                  15.2.0  hdf11a46_19              conda-forge       28kB
#   + libsystemd0                                    261.1  h6f4a2f1_0               conda-forge      566kB
#   + libthrift                                     0.22.0  h7d032f7_2               conda-forge      424kB
#   + libtiff                                        4.7.2  h9d88235_0               conda-forge      452kB
#   + libudev1                                       261.1  h6f4a2f1_0               conda-forge      183kB
#   + libutf8proc                                   2.11.3  hfe17d71_0               conda-forge       86kB
#   + libwebp-base                                   1.6.0  hd42ef1d_0               conda-forge      429kB
#   + libxcb                                        1.17.0  h8a09558_0               conda-forge      396kB
#   + libxcrypt                                     4.4.36  hd590300_1               conda-forge      100kB
#   + libzip                                        1.11.2  h6991a6a_0               conda-forge      109kB
#   + llvmlite                                      0.48.0  py312ha7fb451_1          conda-forge       40MB
#   + locket                                         1.0.0  pyhd8ed1ab_0             conda-forge        8kB
#   + lz4                                            4.4.5  py312h3d67a73_1          conda-forge       44kB
#   + markupsafe                                     3.0.3  py312h8a5da7c_1          conda-forge       26kB
#   + matplotlib-base                               3.11.0  py312hc1765e9_1          conda-forge        9MB
#   + matplotlib-inline                              0.2.2  pyhd8ed1ab_0             conda-forge       16kB
#   + mpi                                            1.0.1  mpich                    conda-forge        7kB
#   + mpich                                          5.0.1  h6f9170e_1               conda-forge       10MB
#   + mpmath                                         1.4.1  pyhd8ed1ab_0             conda-forge      465kB
#   + multidict                                      6.7.1  py312h8a5da7c_0          conda-forge      100kB
#   + munkres                                        1.1.4  pyhd8ed1ab_1             conda-forge       16kB
#   + narwhals                                      2.24.0  pyhcf101f3_0             conda-forge      290kB
#   + nc-time-axis                                   1.4.1  pyhd8ed1ab_1             conda-forge       20kB
#   + nest-asyncio2                                  1.7.2  pyhcf101f3_0             conda-forge       16kB
#   + netcdf-fortran                                 4.6.3  mpi_mpich_h67749c9_0     conda-forge      482kB
#   + netcdf4                                        1.7.4  nompi_py311h498b1eb_108  conda-forge        1MB
#   + nlohmann_json                                 3.12.0  h54a6638_1               conda-forge      136kB
#   + numba                                         0.66.0  py312h6d1259f_0          conda-forge        6MB
#   + numcodecs                                     0.16.5  py312hf79963d_0          conda-forge      813kB
#   + numpy                                         1.26.4  py312heda63a1_0          conda-forge        7MB
#   + oauthlib                                       3.3.1  pyhd8ed1ab_0             conda-forge      102kB
#   + openjpeg                                       2.5.4  h55fea9a_0               conda-forge      355kB
#   + orc                                            2.3.0  h21090e2_0               conda-forge        1MB
#   + pandas                                         2.3.3  py312hf79963d_1          conda-forge       15MB
#   + parallelio                                     2.6.9  mpi_mpich_h462fbca_102   conda-forge      387kB
#   + parso                                          0.8.7  pyhcf101f3_0             conda-forge       82kB
#   + partd                                          1.4.2  pyhd8ed1ab_0             conda-forge       21kB
#   + pcre2                                          10.47  haa7fec5_0               conda-forge        1MB
#   + pexpect                                        4.9.0  pyhd8ed1ab_1             conda-forge       54kB
#   + pillow                                        12.3.0  py312h50c33e8_0          conda-forge        1MB
#   + pint                                          0.25.3  pyhc364b38_0             conda-forge      245kB
#   + pint-xarray                                    0.6.1  pyhd8ed1ab_0             conda-forge       43kB
#   + pixman                                        0.46.4  h54a6638_1               conda-forge      451kB
#   + proj                                           9.8.1  he0df7b0_0               conda-forge        4MB
#   + prometheus-cpp                                 1.3.0  ha5d0236_0               conda-forge      200kB
#   + prompt-toolkit                                3.0.52  pyha770c72_0             conda-forge      274kB
#   + propcache                                      0.5.2  py312h8a5da7c_0          conda-forge       52kB
#   + proto-plus                                    1.28.1  pyhcf101f3_0             conda-forge       44kB
#   + protobuf                                      6.33.5  py312ha7b3241_2          conda-forge      482kB
#   + psutil                                         7.2.2  py312h5253ce2_0          conda-forge      226kB
#   + pthread-stubs                                    0.4  hb9d3cd8_1002            conda-forge        8kB
#   + ptyprocess                                     0.7.0  pyhd8ed1ab_1             conda-forge       19kB
#   + pure_eval                                      0.2.3  pyhd8ed1ab_1             conda-forge       17kB
#   + py-rattler                                    0.25.0  py310h70157a2_1          conda-forge       12MB
#   + py2vega                                        0.7.0  pyhd8ed1ab_0             conda-forge       20kB
#   + pyarrow                                       24.0.0  py312h7900ff3_0          conda-forge       27kB
#   + pyarrow-core                                  24.0.0  py312h2054cf2_0_cpu      conda-forge        5MB
#   + pyasn1                                         0.6.4  pyhcf101f3_0             conda-forge       67kB
#   + pyasn1-modules                                 0.4.2  pyhd8ed1ab_0             conda-forge       96kB
#   + pydantic                                      2.13.4  pyhcf101f3_0             conda-forge      347kB
#   + pydantic-core                                 2.46.4  py312h868fb18_0          conda-forge        2MB
#   + pyerfa                                       2.0.1.5  py310h32771cd_2          conda-forge      296kB
#   + pygments                                      2.20.0  pyhd8ed1ab_0             conda-forge      893kB
# ...
# Unlinking python-3.13.13-h6add32d_100_cp313
# Unlinking pip-26.1.2-pyh145f28c_0
# Unlinking frozendict-2.4.7-py313h07c4f96_0
# Unlinking ruamel.yaml.clib-0.2.15-py313h54dd161_1
# Unlinking pycosat-0.6.6-py313h07c4f96_3
# Unlinking msgpack-python-1.1.2-py313h7037e92_1
# Unlinking cffi-2.0.0-py313hf46b229_1
# Unlinking brotli-python-1.2.0-py313hf159716_1
# Unlinking backports.zstd-1.5.0-py313h18e8e13_0
# Unlinking libmambapy-2.5.0-py313h4616538_0
# Unlinking menuinst-2.4.2-py313h78bf25f_0
# Unlinking ruamel.yaml-0.18.17-py313h54dd161_2
# Unlinking zstandard-0.25.0-py313h54dd161_1
# Unlinking conda-26.3.2-py313h78bf25f_1
# Unlinking archspec-0.2.5-pyhd8ed1ab_0
# Unlinking boltons-25.0.0-pyhd8ed1ab_0
# Unlinking certifi-2026.5.20-pyhd8ed1ab_0
# Unlinking pycparser-3.0-pyhcf101f3_0
# Unlinking charset-normalizer-3.4.7-pyhd8ed1ab_0
# Unlinking idna-3.17-pyhcf101f3_0
# Unlinking hpack-4.1.0-pyhd8ed1ab_0
# Unlinking hyperframe-6.1.0-pyhd8ed1ab_0
# Unlinking h2-4.3.0-pyhcf101f3_0
# Unlinking pysocks-1.7.1-pyha55dd90_7
# Unlinking urllib3-2.7.0-pyhd8ed1ab_0
# Unlinking requests-2.34.2-pyhcf101f3_0
# Unlinking conda-libmamba-solver-26.4.2-pyhd8ed1ab_0
# Unlinking conda-package-streaming-0.12.0-pyhd8ed1ab_0
# Unlinking conda-package-handling-2.4.0-pyh7900ff3_2
# Unlinking distro-1.9.0-pyhd8ed1ab_1
# Unlinking jsonpointer-3.1.1-pyhcf101f3_0
# Unlinking jsonpatch-1.33-pyhd8ed1ab_1
# Unlinking packaging-26.2-pyhc364b38_0
# Unlinking platformdirs-4.10.0-pyhcf101f3_0
# Unlinking pluggy-1.6.0-pyhf9edf01_1
# Unlinking setuptools-82.0.1-pyh332efcf_0
# Unlinking tqdm-4.67.3-pyh8f84b5b_0
# Unlinking truststore-0.10.4-pyhcf101f3_0
# Linking python_abi-3.12-8_cp312
# Linking font-ttf-dejavu-sans-mono-2.37-hab24e00_0
# Linking font-ttf-ubuntu-0.83-h77eed37_3
# Linking font-ttf-inconsolata-3.000-h77eed37_0
# Linking font-ttf-source-code-pro-2.038-h77eed37_0
# Linking mpi-1.0.1-mpich
# Linking fonts-conda-forge-1-hc364b38_1
# Linking fonts-conda-ecosystem-1-0
# Linking libstdcxx-ng-15.2.0-hdf11a46_19
# Linking geos-3.14.1-h480dda7_0
# Linking libutf8proc-2.11.3-hfe17d71_0
# Linking azure-core-cpp-1.16.3-h206d751_0
# Linking libabseil-20260107.1-cxx17_h7b12aa8_0
# Linking aws-c-common-0.14.0-hb03c661_0
# Linking libbrotlicommon-1.2.0-hb03c661_1
# Linking libopentelemetry-cpp-headers-1.27.0-ha770c72_0
# Linking zlib-1.3.2-h25fd6f3_2
# Linking snappy-1.2.2-h03e3b7b_1
# Linking fribidi-1.0.16-hb03c661_0
# Linking graphite2-1.3.15-hecca717_0
# Linking libpng-1.6.58-h421ea60_0
# Linking xorg-libice-1.1.2-hb9d3cd8_0
# Linking pcre2-10.47-haa7fec5_0
# Linking libwebp-base-1.6.0-hd42ef1d_0
# Linking zlib-ng-2.3.3-hceb46e0_1
# Linking pthread-stubs-0.4-hb9d3cd8_1002
# Linking xorg-libxau-1.0.12-hb03c661_1
# Linking xorg-libxdmcp-1.1.5-hb03c661_1
# Linking nlohmann_json-3.12.0-h54a6638_1
# Linking libgfortran5-15.2.0-h68bc16d_19
# Linking gflags-2.3.0-h54a6638_0
# Linking pixman-0.46.4-h54a6638_1
# Linking s2n-1.7.4-h92489ea_1
# Linking yaml-0.2.5-h280c20c_3
# Linking libnsl-2.0.1-hb9d3cd8_1
# Linking libxcrypt-4.4.36-hd590300_1
# Linking lerc-4.1.0-hdb68285_0
# Linking libdeflate-1.25-h17f619e_0
# Linking sqlite-3.53.1-hbc0de68_0
# Linking libjpeg-turbo-3.2.0-hb03c661_0
# Linking libevent-2.1.12-hf998b51_1
# Linking libsodium-1.0.22-h280c20c_1
# Linking libaec-1.1.5-h088129d_0
# Linking libzip-1.11.2-h6991a6a_0
# Linking libnl-3.11.0-hb9d3cd8_0
# Linking libhwloc-2.13.0-default_he001693_1000
# Linking libcap-2.78-hd0affe5_0
# Linking qhull-2020.2-h434a139_5
# Linking libcrc32c-1.1.2-h9c3ff4c_0
# Linking azure-storage-common-cpp-12.14.0-hf596fc9_1
# Linking azure-identity-cpp-1.13.3-h71f81a8_2
# Linking libprotobuf-6.33.5-h538a264_2
# Linking libre2-11-2025.11.05-h0dc7533_1
# Linking aws-c-compression-0.3.2-haa0cbde_2
# Linking aws-c-sdkutils-0.2.5-haa0cbde_0
# Linking aws-c-cal-0.9.14-h78948cc_2
# Linking aws-checksums-0.2.10-haa0cbde_2
# Linking libbrotlienc-1.2.0-hb03c661_1
# Linking libbrotlidec-1.2.0-hb03c661_1
# Linking prometheus-cpp-1.3.0-ha5d0236_0
# Linking blosc-1.21.6-he440d0b_1
# Linking libfreetype6-2.14.3-h73754d4_0
# Linking xorg-libsm-1.2.6-he73a12e_0
# Linking libglib-2.88.2-h0d30a3d_0
# Linking libxcb-1.17.0-h8a09558_0
# Linking libgfortran-15.2.0-h69a702a_19
# Linking glog-0.7.1-hb7133d2_1
# Linking python-3.12.13-hd63d673_0_cpython
# Linking hdf4-4.2.15-h2a13503_7
# Linking libtiff-4.7.2-h9d88235_0
# Linking libthrift-0.22.0-h7d032f7_2
# Linking zeromq-4.3.5-h09e67af_11
# Linking libudev1-261.1-h6f4a2f1_0
# Linking libsystemd0-261.1-h6f4a2f1_0
# Linking azure-storage-blobs-cpp-12.18.0-h74b55db_1
# Linking orc-2.3.0-h21090e2_0
# Linking re2-2025.11.05-h5301d42_1
# Linking aws-c-io-0.26.3-h3bf836e_5
# Linking brotli-bin-1.2.0-hb03c661_1
# Linking libfreetype-2.14.3-ha770c72_0
# Linking xorg-libx11-1.8.13-he1eb515_0
# Linking libopenblas-0.3.33-pthreads_h94d23a6_0
# Linking lcms2-2.19.1-h0c24ade_1
# Linking proj-9.8.1-he0df7b0_0
# Linking openjpeg-2.5.4-h55fea9a_0
# Linking rdma-core-63.0-h192683f_1
# Linking azure-storage-files-datalake-cpp-12.16.0-h1f05bef_1
# Linking libgrpc-1.78.1-h1d1128b_0
# Linking aws-c-http-0.11.0-h6488f85_2
# Linking aws-c-event-stream-0.7.1-h9cf6be0_2
# Linking brotli-1.2.0-hed03a55_1
# Linking fontconfig-2.18.1-h27c8c51_0
# Linking freetype-2.14.3-ha770c72_0
# Linking xorg-libxext-1.3.7-hb03c661_0
# Linking xorg-libxrender-0.9.12-hb9d3cd8_0
# Linking libblas-3.11.0-8_h4a7cf45_openblas
# Linking ucx-1.20.1-hbe80e26_0
#
# To enable CUDA support, UCX requires the CUDA Runtime library (libcudart).
# The library can be installed with the appropriate command below:
#
# * For CUDA 12, run:    conda install cuda-cudart cuda-version=12
# * For CUDA 13, run:    conda install cuda-cudart cuda-version=13
#
# If any of the packages you requested use CUDA then CUDA should already
# have been installed for you.
#
#
# Linking libfabric1-2.6.0-h6b3ec72_0
# Linking libopentelemetry-cpp-1.27.0-h9692893_0
# Linking aws-c-auth-0.10.3-hd2277e8_3
# Linking aws-c-mqtt-0.16.0-h0d2f46f_0
# Linking cairo-1.18.4-he90730b_1
# Linking libcblas-3.11.0-8_h0358290_openblas
# Linking liblapack-3.11.0-8_h47877c9_openblas
# Linking libfabric-2.6.0-ha770c72_0
# Linking libgoogle-cloud-3.6.0-h8d2ee43_0
# Linking aws-c-s3-0.12.6-hb916526_0
# Linking libharfbuzz-14.2.1-h17a8019_1
# Linking mpich-5.0.1-h6f9170e_1
# Linking libgoogle-cloud-storage-3.6.0-hdbdcf42_0
# Linking aws-crt-cpp-0.40.1-h7a9a9d6_1
# Linking libraqm-0.10.5-h6406941_1
# Linking libpnetcdf-1.14.1-mpi_mpich_h0009a5c_101
# Linking hdf5-2.1.0-mpi_mpich_h1816c52_8
# Linking aws-sdk-cpp-1.11.833-hf4c7647_7
# Linking libnetcdf-4.10.0-mpi_mpich_h65e3e28_4
# Linking libarrow-24.0.0-h3e48024_9_cpu
# Linking netcdf-fortran-4.6.3-mpi_mpich_h67749c9_0
# Linking parallelio-2.6.9-mpi_mpich_h462fbca_102
# Linking libparquet-24.0.0-h7376487_9_cpu
# Linking libarrow-compute-24.0.0-h53684a4_9_cpu
# Linking esmf-8.9.1-mpi_mpich_ha43e4ac_103
# Linking libarrow-acero-24.0.0-h635bf11_9_cpu
# Linking libarrow-dataset-24.0.0-h635bf11_9_cpu
# Linking libarrow-substrait-24.0.0-hb4dd7c2_9_cpu
# Linking wheel-0.47.0-pyhd8ed1ab_0
# Linking pip-26.1.2-pyh8b19718_0
# Linking cached_property-1.5.2-pyha770c72_2
# Linking filelock-3.30.2-pyhd8ed1ab_0
# Linking webencodings-0.5.1-pyhd8ed1ab_3
# Linking sniffio-1.3.1-pyhd8ed1ab_2
# Linking gast-0.7.0-pyhd8ed1ab_0
# Linking nest-asyncio2-1.7.2-pyhcf101f3_0
# Linking widgetsnbextension-4.0.15-pyhd8ed1ab_0
# Linking jupyterlab_widgets-3.0.16-pyhcf101f3_1
# Linking comm-0.2.3-pyhe01879c_0
# Linking parso-0.8.7-pyhcf101f3_0
# Linking ptyprocess-0.7.0-pyhd8ed1ab_1
# Linking wcwidth-0.8.2-pyhd8ed1ab_0
# Linking tomli-2.4.1-pyhcf101f3_0
# Linking colorama-0.4.6-pyhd8ed1ab_1
# Linking pyasn1-0.6.4-pyhcf101f3_0
# Linking pure_eval-0.2.3-pyhd8ed1ab_1
# Linking executing-2.2.1-pyhd8ed1ab_0
# Linking asttokens-3.0.2-pyhd8ed1ab_0
# Linking python-installer-1.0.1-pyh332efcf_0
# Linking jmespath-1.1.0-pyhcf101f3_1
# Linking uncompresspy-0.4.1-pyhd8ed1ab_0
# Linking mpmath-1.4.1-pyhd8ed1ab_0
# Linking soupsieve-2.8.4-pyhd8ed1ab_0
# Linking xyzservices-2026.3.0-pyhd8ed1ab_0
# Linking narwhals-2.24.0-pyhcf101f3_0
# Linking traitlets-5.15.1-pyhcf101f3_0
# Linking pygments-2.20.0-pyhd8ed1ab_0
# Linking blinker-1.9.0-pyhff2d567_0
# Linking six-1.17.0-pyhe01879c_1
# Linking python-multipart-0.0.32-pyhcf101f3_0
# Linking itsdangerous-2.2.0-pyhd8ed1ab_1
# Linking attrs-26.1.0-pyhcf101f3_0
# Linking aiohappyeyeballs-2.7.1-pyhd8ed1ab_0
# Linking astropy-iers-data-0.2026.7.13.0.54.2-pyhd8ed1ab_0
# Linking pyshp-3.1.4-pyhcf101f3_0
# Linking munkres-1.1.4-pyhd8ed1ab_1
# Linking pyparsing-3.3.2-pyhcf101f3_0
# Linking cycler-0.12.1-pyhcf101f3_2
# Linking tomli-w-1.2.0-pyhd8ed1ab_0
# Linking pytz-2026.2-pyhcf101f3_0
# Linking python-tzdata-2026.3-pyhd8ed1ab_0
# Linking cpython-3.12.13-py312hd8ed1ab_0
# Linking zict-3.0.0-pyhd8ed1ab_1
# Linking tblib-3.2.2-pyhcf101f3_0
# Linking sortedcontainers-2.4.0-pyhd8ed1ab_1
# Linking click-8.4.2-pyhc90fa1f_0
# Linking fastcore-2.1.1-pyhc364b38_0
# Linking decorator-5.3.1-pyhd8ed1ab_0
# Linking zipp-4.1.0-pyhcf101f3_0
# Linking toolz-1.1.0-pyhd8ed1ab_1
# Linking entrypoints-0.4-pyhd8ed1ab_1
# Linking cloudpickle-3.1.2-pyhcf101f3_1
# Linking appdirs-1.4.4-pyhd8ed1ab_1
# Linking typing_extensions-4.16.0-pyhcf101f3_0
# Linking locket-1.0.0-pyhd8ed1ab_0
# Linking frozendict-2.4.7-pyh851646a_2
# Linking fsspec-2026.6.0-pyhd8ed1ab_0
# Linking cached-property-1.5.2-hd8ed1ab_2
# Linking bleach-6.4.0-pyhcf101f3_0
# Linking py2vega-0.7.0-pyhd8ed1ab_0
# Linking jedi-0.20.0-pyhcf101f3_0
# Linking pexpect-4.9.0-pyhd8ed1ab_1
# Linking prompt-toolkit-3.0.52-pyha770c72_0
# Linking pyproject_hooks-1.2.0-pyhd8ed1ab_1
# Linking rsa-4.9.1-pyhd8ed1ab_0
# Linking pyasn1-modules-0.4.2-pyhd8ed1ab_0
# Linking stack_data-0.6.3-pyhd8ed1ab_1
# Linking traittypes-0.2.3-pyh332efcf_0
# Linking jupyter_core-5.9.1-pyhc90fa1f_0
# Linking matplotlib-inline-0.2.2-pyhd8ed1ab_0
# Linking ipython_pygments_lexers-1.1.1-pyhd8ed1ab_0
# Linking html5lib-1.1-pyhd8ed1ab_2
# Linking pyu2f-0.1.5-pyhd8ed1ab_1
# Linking python-dateutil-2.9.0.post0-pyhe01879c_2
# Linking python-gil-3.12.13-hd8ed1ab_0
# Linking importlib-metadata-9.0.0-pyhcf101f3_0
# Linking aioitertools-0.13.0-pyhd8ed1ab_0
# Linking exceptiongroup-1.3.1-pyhd8ed1ab_0
# Linking h11-0.16.0-pyhcf101f3_1
# Linking pyjwt-2.13.0-pyhcf101f3_0
# Linking typing-inspection-0.4.2-pyhcf101f3_2
# Linking typing-extensions-4.16.0-h69aa097_0
# Linking partd-1.4.2-pyhd8ed1ab_0
# Linking botocore-1.43.0-pyhd8ed1ab_0
# Linking _python_abi3_support-1.0-hd8ed1ab_3
# Linking python-build-1.5.0-pyhc364b38_0
# Linking anyio-4.14.2-pyhcf101f3_0
# Linking httpcore2-2.3.0-pyhcf101f3_0
# Linking uvicorn-0.51.0-pyhc90fa1f_0
# Linking annotated-types-0.7.0-pyhd8ed1ab_1
# Linking beautifulsoup4-4.15.0-pyha770c72_0
# Linking flexparser-0.4-pyhd8ed1ab_1
# Linking flexcache-0.3-pyhd8ed1ab_1
# Linking httpcore-1.0.9-pyh29332c3_0
# Linking starlette-1.3.1-pyhcf101f3_0
# Linking httpx2-2.3.0-pyhcf101f3_0
# Linking pint-0.25.3-pyhc364b38_0
# Linking httpx-0.28.1-pyhd8ed1ab_0
# Linking unearth-0.18.2-pyhd8ed1ab_0
# Linking debugpy-1.8.21-py312h8285ef7_0
# Linking wrapt-2.2.2-py312h4c3975b_0
# Linking protobuf-6.33.5-py312ha7b3241_2
# Linking markupsafe-3.0.3-py312h8a5da7c_1
# Linking apsw-3.53.1.0-py312h4c3975b_0
# Linking google-crc32c-1.8.0-py312h03f33d3_1
# Linking propcache-0.5.2-py312h8a5da7c_0
# Linking multidict-6.7.1-py312h8a5da7c_0
# Linking frozenlist-1.8.0-py312h447239a_0
# Linking pyproj-3.7.2-py312hbc8341d_4
# Linking unicodedata2-17.0.1-py312h4c3975b_0
# Linking pillow-12.3.0-py312h50c33e8_0
# Linking kiwisolver-1.5.0-py312h0a2e395_0
# Linking llvmlite-0.48.0-py312ha7fb451_1
# Linking pyarrow-core-24.0.0-py312h2054cf2_0_cpu
# Linking lz4-4.4.5-py312h3d67a73_1
# Linking tornado-6.5.7-py312h4c3975b_0
# Linking psutil-7.2.2-py312h5253ce2_0
# Linking pyyaml-6.0.3-py312h8a5da7c_1
# Linking numpy-1.26.4-py312heda63a1_0
# Linking ruamel.yaml.clib-0.2.15-py312h5253ce2_1
# Linking pycosat-0.6.6-py312h4c3975b_4
# Linking msgpack-python-1.2.1-py312h0a2e395_1
# Linking cffi-2.1.0-py312h460c074_0
# Linking brotli-python-1.2.0-py312hdb49522_1
# Linking backports.zstd-1.6.0-py312h90b7ffd_0
# Linking libmambapy-2.5.0-py312h1ca65c7_0
# Linking menuinst-2.5.1-py312h20c3967_0
# Linking cytoolz-1.1.0-py312h4c3975b_2
# Linking grpcio-1.78.1-py312h39ee1c6_0
# Linking pydantic-core-2.46.4-py312h868fb18_0
# Linking pyzmq-27.1.0-py312hda471dd_3
# Linking py-rattler-0.25.0-py310h70157a2_1
# Linking yarl-1.24.2-py312h8a5da7c_0
# Linking fonttools-4.63.0-py312h8a5da7c_0
# Linking pyarrow-24.0.0-py312h7900ff3_0
# Linking h5py-3.16.0-nompi_py312ha829cd9_102
# Linking bottleneck-1.6.0-np2py312hfb8c2c5_3
# Linking pyerfa-2.0.1.5-py310h32771cd_2
# Linking contourpy-1.3.3-py312h0a2e395_4
# Linking cftime-1.6.5-py312h4f23490_1
# Linking scipy-1.17.1-py312h54fa4ab_1
# Linking shapely-2.1.2-py312h383787d_2
# Linking numba-0.66.0-py312h6d1259f_0
# Linking pandas-2.3.3-py312hf79963d_1
# Linking ruamel.yaml-0.18.17-py312h5253ce2_2
# Linking cryptography-49.0.0-py312ha4b625e_0
# Linking zstandard-0.25.0-py312h5253ce2_1
# Linking astropy-base-7.2.0-py312h4f23490_0
# Linking matplotlib-base-3.11.0-py312hc1765e9_1
# Linking netcdf4-1.7.4-nompi_py311h498b1eb_108
# Linking cartopy-0.25.0-py312hf79963d_1
# Linking deprecated-1.3.1-pyhd8ed1ab_1
# Linking googleapis-common-protos-1.75.0-pyhcf101f3_0
# Linking proto-plus-1.28.1-pyhcf101f3_0
# Linking jinja2-3.1.6-pyhcf101f3_1
# Linking apswutils-0.1.2-pyhcf101f3_0
# Linking google-resumable-media-2.8.0-pyhd8ed1ab_0
# Linking aiosignal-1.4.0-pyhd8ed1ab_0
# Linking ipython-9.15.0-pyh53cf698_0
# Linking donfig-0.8.1.post1-pyhd8ed1ab_1
# Linking dask-core-2026.7.1-pyhc364b38_0
# Linking jplephem-2.24-pyha4b2019_1
# Linking esmpy-8.9.1-pyhdfbf58e_0
# Linking pydantic-2.13.4-pyhcf101f3_0
# Linking jupyter_client-8.9.1-pyhcf101f3_0
# Linking sparse-0.19.0-pyhc364b38_0
# Linking xarray-2024.2.0-pyhd8ed1ab_0
# Linking oauthlib-3.3.1-pyhd8ed1ab_0
# Linking nc-time-axis-1.4.1-pyhd8ed1ab_1
# Linking googleapis-common-protos-grpc-1.75.0-pyhcf101f3_0
# Linking grpcio-status-1.78.1-pyhcf101f3_0
# Linking bokeh-3.9.1-pyhd8ed1ab_0
# Linking fastlite-0.2.3-pyhcf101f3_0
# Linking ipywidgets-8.1.8-pyhd8ed1ab_0
# Linking distributed-2026.7.1-pyhc364b38_0
# Linking ipykernel-7.3.0-pyha191276_0
# Linking pint-xarray-0.6.1-pyhd8ed1ab_0
# Linking xarray-datatree-0.0.14-pyhd8ed1ab_0
# Linking cf_xarray-0.10.11-pyhd8ed1ab_0
# Linking requests-oauthlib-2.0.0-pyhd8ed1ab_1
# Linking grpc-google-iam-v1-0.14.4-pyhcf101f3_0
# Linking python-fasthtml-0.14.6-pyhc364b38_0
# Linking bqscales-0.3.7-pyhd8ed1ab_1
# Linking dask-2026.7.1-pyhc364b38_0
# Linking xmip-0.7.2-pyhd8ed1ab_1
# Linking cf-xarray-0.10.11-pyhd8ed1ab_1
# Linking fastprogress-1.1.6-pyhd8ed1ab_0
# Linking bqplot-0.13.1-pyhcf101f3_0
# Linking intake-0.7.0-pyhd8ed1ab_0
# Linking xesmf-0.9.2-pyhd8ed1ab_0
# Linking ipydatagrid-1.4.0-pyhcf101f3_2
# Linking numcodecs-0.16.5-py312hf79963d_0
# Linking aiohttp-3.14.1-py312h5d8c7f2_0
# Linking conda-26.5.3-py312h20c3967_2
# Linking zarr-3.1.5-pyhcf101f3_0
# Linking google-auth-2.56.0-pyhcf101f3_0
# Linking aiobotocore-3.7.0-pyhcf101f3_0
# Linking conda-lockfiles-0.2.1-pyhd8ed1ab_0
# Linking intake-esm-2024.2.6-pyhd8ed1ab_2
# Linking google-api-core-2.31.0-pyhcf101f3_0
# Linking google-auth-oauthlib-1.4.0-pyhd8ed1ab_0
# Linking s3fs-2026.6.0-pyhd8ed1ab_0
# Linking conda-self-0.2.0-pyhd8ed1ab_0
# Linking google-cloud-core-2.6.0-pyhcf101f3_1
# Linking google-cloud-storage-control-1.10.0-pyhcf101f3_0
# Linking astropy-7.2.0-pyhd8ed1ab_0
# Linking conda-index-0.12.1-pyhd8ed1ab_0
# Linking google-cloud-storage-3.13.0-pyhcf101f3_0
# Linking xarrayutils-2.0.1-pyhd8ed1ab_0
# Linking gcsfs-2026.7.0-pyhd8ed1ab_0
# Linking conda-pypi-0.11.0-py312h20c3967_1
# Linking conda-rattler-solver-0.1.1-pyhcf101f3_0
# Linking archspec-0.2.5-pyhd8ed1ab_0
# Linking boltons-25.0.0-pyhd8ed1ab_0
# Linking certifi-2026.5.20-pyhd8ed1ab_0
# Linking pycparser-3.0-pyhcf101f3_0
# Linking charset-normalizer-3.4.7-pyhd8ed1ab_0
# Linking idna-3.17-pyhcf101f3_0
# Linking hpack-4.1.0-pyhd8ed1ab_0
# Linking hyperframe-6.1.0-pyhd8ed1ab_0
# Linking h2-4.3.0-pyhcf101f3_0
# Linking pysocks-1.7.1-pyha55dd90_7
# Linking urllib3-2.7.0-pyhd8ed1ab_0
# Linking requests-2.34.2-pyhcf101f3_0
# Linking conda-libmamba-solver-26.4.2-pyhd8ed1ab_0
# Linking conda-package-streaming-0.12.0-pyhd8ed1ab_0
# Linking conda-package-handling-2.4.0-pyh7900ff3_2
# Linking distro-1.9.0-pyhd8ed1ab_1
# Linking jsonpointer-3.1.1-pyhcf101f3_0
# Linking jsonpatch-1.33-pyhd8ed1ab_1
# Linking packaging-26.2-pyhc364b38_0
# Linking platformdirs-4.10.0-pyhcf101f3_0
# Linking pluggy-1.6.0-pyhf9edf01_1
# Linking setuptools-82.0.1-pyh332efcf_0
# Linking tqdm-4.67.3-pyh8f84b5b_0
# Linking truststore-0.10.4-pyhcf101f3_0
#
# Transaction finished

# %%
# installations ( uncomment and run this cell ONLY when using google colab or kaggle )

# the newest version of xESMF (and esmPY) requires an environment variable to be set upon environment activation.
# for Google Colab users you will need to set this manually, see this page for reference: https://github.com/esmf-org/esmf/pull/151
# to do this uncomment the following lines before running the cell:

# Restart the session, uncomment and run below

# import sys, os
sys.path.insert(0, '/opt/mf/lib/python3.12/site-packages')
os.environ['ESMFMKFILE'] = '/opt/mf/lib/esmf.mk'

# import xesmf as xe
print('xesmf', xe.__version__, 'ready')

# %%
# imports

import intake
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import xesmf as xe

from xmip.preprocessing import combined_preprocessing

from datatree import DataTree

import cartopy.crs as ccrs

# %%
# @title Install and import feedback gadget

# !pip3 install vibecheck datatops --quiet

from vibecheck import DatatopsContentReviewContainer
def content_review(notebook_section: str):
    return DatatopsContentReviewContainer(
        "",  # No text prompt
        notebook_section,
        {
            "url": "https://pmyvdlilci.execute-api.us-east-1.amazonaws.com/klab",
            "name": "comptools_4clim",
            "user_key": "l5jpxuee",
        },
    ).render()


feedback_prefix = "W1D5_T7"

# %%
# @title Figure settings
import ipywidgets as widgets  # interactive display

plt.style.use(
    "https://raw.githubusercontent.com/neuromatch/climate-course-content/main/cma.mplstyle"
)

# %matplotlib inline

# %%
# @title Video 1: Introduction to Earth System Models

from ipywidgets import widgets
from IPython.display import YouTubeVideo
from IPython.display import IFrame
from IPython.display import display


class PlayVideo(IFrame):
  def __init__(self, id, source, page=1, width=400, height=300, **kwargs):
    self.id = id
    if source == 'Bilibili':
      src = f'https://player.bilibili.com/player.html?bvid={id}&page={page}'
    elif source == 'Osf':
      src = f'https://mfr.ca-1.osf.io/render?url=https://osf.io/download/{id}/?direct%26mode=render'
    super(PlayVideo, self).__init__(src, width, height, **kwargs)


def display_videos(video_ids, W=400, H=300, fs=1):
  tab_contents = []
  for i, video_id in enumerate(video_ids):
    out = widgets.Output()
    with out:
      if video_ids[i][0] == 'Youtube':
        video = YouTubeVideo(id=video_ids[i][1], width=W,
                             height=H, fs=fs, rel=0)
        print(f'Video available at https://youtube.com/watch?v={video.id}')
      else:
        video = PlayVideo(id=video_ids[i][1], source=video_ids[i][0], width=W,
                          height=H, fs=fs, autoplay=False)
        if video_ids[i][0] == 'Bilibili':
          print(f'Video available at https://www.bilibili.com/video/{video.id}')
        elif video_ids[i][0] == 'Osf':
          print(f'Video available at https://osf.io/{video.id}')
      display(video)
    tab_contents.append(out)
  return tab_contents


video_ids = [('Youtube', '1ErpqVCb2wQ'), ('Bilibili', 'BV1YgGDepEL6')]
tab_contents = display_videos(video_ids, W=730, H=410)
tabs = widgets.Tab()
tabs.children = tab_contents
for i in range(len(tab_contents)):
  tabs.set_title(i, video_ids[i][0])
display(tabs)

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_Recap_Earth_System_Models_Video")

# %%
# @markdown
from ipywidgets import widgets
from IPython.display import IFrame

link_id = "x3kwy"

print(f"If you want to download the slides: https://osf.io/download/{link_id}/")
IFrame(src=f"https://mfr.ca-1.osf.io/render?url=https://osf.io/{link_id}/?direct%26mode=render%26action=download%26mode=render", width=854, height=480)

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_Recap_Earth_System_Models_Slides")

# %% [markdown]
# # Section 1: Accessing Earth System Model data

# %% [markdown]
# In the previous tutorials we developed some simple conceptual climate models. Here we will jump to the most complex type of climate model, an **Earth System Model (ESM)**.
#
# ESMs include the physical processes typical of General Circulation Models (GCMs), but also include chemical and biological changes within the climate system (e.g. changes in vegetation, biomes, atmospheric CO$_2$).

# %% [markdown]
# The several systems simulated in an ESM (ocean, atmosphere, cryosphere, land) are coupled to each other, and each system has its own variables, physics, and discretizations -- both of the spatial grid and the timestep.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/73/AtmosphericModelSchematic.png" alt= “EarthSystemModel” width="420" height="400">
#
# Atmospheric Model Schematic (Credit: [Wikipedia](https://upload.wikimedia.org/wikipedia/commons/7/73/AtmosphericModelSchematic.png))

# %% [markdown]
# The one specific ESM we will analyze here is the [**Taiwan Earth System Model version 1** (**TaiESM1**)](https://gmd.copernicus.org/articles/13/3887/2020/).
#
# TaiESM1 was developed by modifying an earlier version of CESM2, [the Community Earth System Model, version 2](https://www.cesm.ucar.edu/models/cesm2), to include different parameterizations (i.e., physics). As a result, the two models are distinct from each other.

# %% [markdown]
# ## Section 1.1: Finding & Opening CMIP6 Data with Xarray
#
# Massive projects like [CMIP6](https://wcrp-cmip.org/cmip-phase-6-cmip6/) can contain millions of datasets. For most practical applications we only need a subset of the data, which we can select by specifying exactly which data sets we need.
#
#  **Although we will only work with monthly SST (ocean) data today, the methods introduced can easily be applied/extended to load and analyze other CMIP6 variables, including from other components of the Earth system.**
#
# There are many ways to access the CMIP6 data, but here we will show a workflow using an [intake-esm](https://intake-esm.readthedocs.io/en/stable/) catalog object based on a CSV file that is maintained by the [pangeo community](https://pangeo.io/). Additional methods to access CMIP data are discussed in our [CMIP Resource Bank](https://github.com/neuromatch/climate-course-content/blob/main/tutorials/CMIP/CMIP_resource_bank.md).

# %%
col = intake.open_esm_datastore(
    "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
)  # open an intake catalog containing the Pangeo CMIP cloud data
col

# %% [markdown]
# We just loaded the full collection of Pangeo cloud datasets into an [intake catalog](https://intake-esm.readthedocs.io/en/stable/reference/esm-catalog-spec.html). The naming conventions of CMIP6 data sets are standardized across all models and experiments, which allows us to access multiple related data sets with efficient code.
#
# In the intake catalog above, we can see several different aspects of the CMIP6 naming conventions, including the following:
#
# 1. ***variable_id***: The variable(s) of interest
#    * Here we'll be working with SST, which in CMIP6 SST is called *tos*
# 2. ***source_id***: The CMIP6 model(s) that we want data from.
# 3. ***table_id***: The origin system and output frequency desired of the variable(s)
#    * Here we use *Omon* - data from the ocean model at monthly resolution.
# 4. ***grid_id***: The grid that we want the data to be on.
#    * Here we use *gn*  which is data on the model's *native* grid. Some models also provide *gr* (*regridded* data) and other grid options.
# 5. ***experiment_id***: The CMIP6 experiments that we want to analyze
#    * We will load one experiment: *ssp585*. We'll discuss scenarios more in the next tutorial.
# 6. ***member_id***: this distinguishes simulations if the same model is run repeatedly for an experiment
#    * We use *r1i1p1f1* for now, but will explore this in a later tutorial
#
# Each of these terms is called a *facet* in CMIP vocabulary. To learn more about CMIP and the possible facets please see our [CMIP Resource Bank](https://github.com/neuromatch/climate-course-content/blob/main/tutorials/CMIP/CMIP_resource_bank.md) and the [CMIP website](https://wcrp-cmip.org/).

# %% [markdown]
# Try running
#
# ```
# col.df['source_id'].unique()
# ```
# in the next cell to get a list of all available models!

# %% [markdown]
# Now we will create a subset according to the provided facets using the `.search()` method, and finally open the cloud-stored [zarr stores](https://pangeo-data.github.io/pangeo-cmip6-cloud/overview.html) into Xarray datasets.
#
# The data returned are Xarray datasets that contain [dask arrays](https://docs.dask.org/en/stable/array.html). These are 'lazy', meaning the actual data will only be loaded when a computation is performed. What is loaded here is only the metadata, which enables us to inspect the data (e.g. the dimensionality/variable units) without loading in GBs or TBs of data!
#
# A subtle but important step in the opening stage is the use of a preprocessing function! By passing `preprocess=combined_preprocessing` we apply crowdsourced fixes from the [xMIP](https://github.com/jbusecke/xmip) package to each dataset. This ensures consistent naming of dimensions (and other convenient things - see [here](https://cmip6-preprocessing.readthedocs.io/en/latest/tutorial.html) for more).

# %% [markdown]
# **Although we will only work with monthly SST (ocean) data today, the methods introduced can easily be applied/extended to load and analyze other CMIP6 variables, including from other components of the Earth system.**

# %%
# from the full `col` object, create a subset using facet search
cat = col.search(
    source_id=["TaiESM1"
               #,"MPI-ESM1-2-LR" # alternative model specification
              ],
    variable_id="tos",
    member_id="r1i1p1f1",
    table_id="Omon",
    grid_label="gn",
    experiment_id=["ssp585",
                   #"ssp245",
                   "historical"],
    require_all_on=[
        "source_id"
    ],  # make sure that we only get models which have all of the above experiments
)

# convert the sub-catalog into a datatree object, by opening each dataset into an xarray.Dataset (without loading the data)
kwargs = dict(
    preprocess=combined_preprocessing,  # apply xMIP fixes to each dataset
    xarray_open_kwargs=dict(
        use_cftime=True
    ),  # ensure all datasets use the same time index
    storage_options={
        "token": "anon"
    },  # anonymous/public authentication to google cloud storage
)

cat.esmcat.aggregation_control.groupby_attrs = ["source_id", "experiment_id"]
dt = cat.to_datatree(**kwargs)

# %%
cat.keys()

# %% [markdown]
# ## Section 1.2: Checking the CMIP6 DataTree
#
# We now have a "[datatree](https://xarray-datatree.readthedocs.io/en/latest/quick-overview.html)" containing the data we searched for. A datatree is a high-level container of Xarray data, useful for organizing many related datasets together. You can think of a single `DataTree` object as being like a (nested) dictionary of `xarray.Dataset` objects. Each dataset in the tree is known as a "node" or "group", and we can also have empty nodes.
#
# *This `DataTree` object may seem overly complicated with just a couple of datasets, but it will prove to be very useful in later tutorials where you will work with multiple models, experiments, and ensemble members.*
#
# You can explore the nodes of the tree and its contents interactively in a similar way to how you can explore the contents of an `xarray.Dataset`. Click on the arrows to expand the information about the datatree below:

# %%
dt

# %% [markdown]
# Each group in the tree is stored under a corresponding `name`, and we can select nodes via their name. The real usefulness of a datatree comes from having many groups at different depths, analogous to how one might store files in nested directories (e.g. `day1/experiment1/data.txt`, `day1/experiment2/data.txt` etc.).
#
# In our case, the particular datatree object has different CMIP models and different experiments stored at distinct levels of the tree. This is useful because we can select just one experiment for one model, or all experiments for one model, or all experiments for all models!
#
# We can also apply Xarray operations (e.g. taking the average using the `.mean()` method) over all the data in a tree at once, just by calling that same method on the `DataTree` object. We can even map custom functions over all nodes in the tree using [`dt.map_over_subtree(my_function)`](https://xarray-datatree.readthedocs.io/en/latest/generated/datatree.map_over_subtree.html#datatree-map-over-subtree).
#
# All the operations below can be accomplished without using datatrees, but it saves us many lines of code as we don't have to use `for` loops over all our the different datasets. For more information about datatree see the [documentation here](https://xarray-datatree.readthedocs.io/en/latest/index.html).

# %% [markdown]
# Now, let's pull out a single model (**_TaiESM1_**) and experiment (**_ssp585_**) from our datatree:

# %%
ssp585 = dt["TaiESM1"]["ssp585"].ds
ssp585

# %% [markdown]
# We now have a more familiar single Xarray dataset containing a single Data variable `tos`. We can access the DataArray for our `tos` variable as usual, and inspect its attributes like `long_name` and `units`:

# %%
ssp585.tos

# %% [markdown]
# # Section 2: Plotting maps of Sea Surface Temperature

# %% [markdown]
# Now that we have the model dataset organized within this datatree `dt` we can plot the datasets. Let's start by plotting a map of SST from TaiESM in July 2024.
#
# *Note that CMIP6 experiments were run several years ago, so the cut-off between **past** (observed forcing) and **future** (scenario-based/projected forcing) was at the start of 2015. This means that July 2024 is about 9 years into the CMIP6 **future** and so it is unlikely to look exactly like Earth's current SST state.*

# %%
# Set up our figure with a Cartopy map projection
fig, (ax_present) = plt.subplots(subplot_kw={"projection": ccrs.Robinson()}
)

# select the model data for July 2024
sst_present = ssp585.tos.sel(time="2024-07").squeeze()
# note that .squeeze() just removes singleton dimensions

# plot the model data
sst_present.plot(
    ax=ax_present,
    x="lon",
    y="lat",
    transform=ccrs.PlateCarree(),
    vmin=-2,
    vmax=30,
    cmap="magma",
    robust=True,
)
ax_present.coastlines()
ax_present.set_title("July 2024")

# %% [markdown]
# ## Coding Exercises 2
#
# Now that we can plot maps of CMIP6 data, let's look at some projected future changes using this data!
#
# In this coding exercise your goals are to:
# 1. Create a map of the projected sea surface temperature in July 2100 under the SSP5-8.5 high-emissions scenario (we'll discuss scenarios in the next mini-lecture) using data from the *TaiESM1* CMIP6 model.
# 2. Create a map showing how this sea surface temperature (SST, tos) projection is different from the current (July 2024) sea surface temperature in this model
# 3. Plot a similar map for this model that shows how *January* 2100 is different from *January* 2024
#
# To get you started, we have provided code to load the required data set into a variable called *sst_ssp585*, and we have plotted the current (July 2024) sea surface temperature from this data set.
#
# *Note: differences between two snapshots of SST are not the same as the **anomalies** that you encountered earlier in the course, which were the difference relative to the average during a reference period.*

# %%
# select just a single model and experiment
sst_ssp585 = dt["TaiESM1"]["ssp585"].ds.tos

fig, ([ax_present, ax_future], [ax_diff_july, ax_diff_jan]) = plt.subplots(
    ncols=2, nrows=2, figsize=[12, 6], subplot_kw={"projection": ccrs.Robinson()}
)

# plot a timestep for 2024
sst_present = sst_ssp585.sel(time="2024-07").squeeze()
sst_present.plot(
    ax=ax_present,
    x="lon",
    y="lat",
    transform=ccrs.PlateCarree(),
    vmin=-2,
    vmax=30,
    cmap="magma",
    robust=True,
)
ax_present.coastlines()
ax_present.set_title("July 2024")

# repeat for 2100
# complete the following line to extract data for July 2100
sst_future = ...
_ = ...
ax_future.coastlines()
ax_future.set_title("July 2100")

# now find the difference between July 2100 and July 2024
# complete the following line to extract the July difference
sst_difference_july = ...
_ = ...
ax_diff_july.coastlines()
ax_diff_july.set_title("2100 vs. 2024 Difference (July)")

# finally, find the difference between January of the two years used above
# complete the following line to extract the January difference
sst_difference_jan = ...
_ = ...
ax_diff_jan.coastlines()
ax_diff_jan.set_title("2100 vs. 2024 Difference (January)")

# %% [markdown]
# [*Click for solution*](https://github.com/neuromatch/climate-course-content/tree/main/tutorials/W1D5_IntroductiontoClimateModeling/solutions/W1D5_Tutorial7_Solution_0ff3ece9.py)
#
# *Example output:*
#
# <img alt='Solution hint' align='left' width=1174.0 height=578.0 src=https://raw.githubusercontent.com/neuromatch/climate-course-content/main/tutorials/W1D5_IntroductiontoClimateModeling/static/W1D5_Tutorial7_Solution_0ff3ece9_1.png>

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_Coding_Exercises_2")

# %% [markdown]
# ## Questions 2: Climate Connection
#
# 1.   *Comparing only the top two panels*, how is the July SST projected to change in this particular model simulation? Do these changes agree with the map of July change that you plotted in the bottom left, and are these changes easier to see in this bottom map?
# 2.   In what ways are the July and January maps similar or dissimilar, and can you think of any physical explanations for these (dis)similarities?
# 3. Why do you think the color bar axes vary? (i.e., the top panels say "*Sea Surface Temperature [$^oC$]*" while the bottom panels say "*tos*")
#
# Many of the changes seen in the maps are a result of a changing climate under this high-emissions scenarios. However, keep in mind that these are differences between two months that are almost 80 years apart, so some of the changes are due to weather/synoptic differences between these particular months.

# %% [markdown]
# [*Click for solution*](https://github.com/neuromatch/climate-course-content/tree/main/tutorials/W1D5_IntroductiontoClimateModeling/solutions/W1D5_Tutorial7_Solution_a29ea5f6.py)

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_Questions_2")

# %% [markdown]
# # Section 3: Horizontal Regridding
#
# Many CMIP6 models use distinct spatial grids, we call this the model's *native grid*.
#
# You are likely familiar with the *regular latitude-longitude* grid where we separate the planet into boxes that have a fixed latitude and longitude span like this image we saw in the tutorial:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/4c/Azimutalprojektion-schief_kl-cropped.png" alt= "Lat_Lon_Grid" width="250" height="250">

# %% [markdown]
# ## Section 3.1: A Rotated Pole grid
#
# Let's look at the grid used for the ocean component of the *TaiESM1* CMIP6 model:

# %%
# create a scatter plot with a symbol at the center of each ocean grid cell in TaiESM1
fig, ax = plt.subplots()
ax.scatter(x=sst_ssp585.lon, y=sst_ssp585.lat, s=0.1)
ax.set_ylabel("Latitude")
ax.set_xlabel("Longitude")
ax.set_title("Grid cell locations in TaiESM1");

# %% [markdown]
# ### Questions 3.1
#
# 1. How would this plot look for a *regular latitude-longitude* grid like the globe image shown above and in the slides? In what ways is the TaiESM1 grid different from this regular grid?
# 2. Can you think of a reason the Northern and Southern Hemisphere ocean grids differ?*
#
# **Hint: from an oceanographic context, how are the North and South poles different from each other?*

# %% [markdown]
# [*Click for solution*](https://github.com/neuromatch/climate-course-content/tree/main/tutorials/W1D5_IntroductiontoClimateModeling/solutions/W1D5_Tutorial7_Solution_aabbdc88.py)

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_Questions_3_1")

# %% [markdown]
# ## Section 3.2: Regridding to a regular grid
#
# If you want to compare spatial maps from different models/observations, e.g. plot a map averaged over several models or the bias of this map relative to observations, you must first ensure the data from all the models (and observations) is on the same spatial grid. This is where regridding becomes essential!
#
# > Regridding is applied lazily, but it is still taking time to compute *when* it is applied. So if you want to compare for example the mean over time of several models it is often much quicker to compute the mean in time over the native grid and then regrid the result of that, instead of regridding each timestep and then calculating the mean!

# %%
# define a 'target' grid. This is simply a regular lon/lat grid that we will interpolate our data on
ds_target = xr.Dataset(
    {
        "lat": (["lat"], np.arange(-90, 90, 1.0), {"units": "degrees_north"}),
        "lon": (["lon"], np.arange(0, 360, 1.0), {"units": "degrees_east"}),
    }
)  # you can try to modify the parameters above to e.g. just regrid onto a region or make the resolution coarser etc
ds_target

# %%
# define the regridder object (from our source dataarray to the target)
regridder = xe.Regridder(
    sst_ssp585, ds_target, "bilinear", periodic=True
)  # this takes some time to calculate a weight matrix for the regridding
regridder

# %%
# now we can apply the regridder to our data
sst_ssp585_regridded = regridder(sst_ssp585)  # this is a lazy operation!
# so it does not slow us down significantly to apply it to the full data!
# we can work with this array just like before and the regridding will only be
# applied to the parts that we later load into memory or plot.
sst_ssp585_regridded

# %%
# compare the shape to the original array
sst_ssp585

# %% [markdown]
# ## Section 3.3: Visually Comparing Data with Different Map Projections
#
# Let's use the code from above to plot a map of the model data on its original (*native*) grid, and a map of the model data after it is regridded.

# %%
fig, ([ax_regridded, ax_native]) = plt.subplots(
    ncols=2, figsize=[12, 3], subplot_kw={"projection": ccrs.Robinson()}
)

# Native grid data
sst_future = sst_ssp585.sel(time="2100-07").squeeze()
sst_future.plot(
    ax=ax_native,
    x="lon",
    y="lat",
    transform=ccrs.PlateCarree(),
    vmin=-2,
    vmax=30,
    cmap="magma",
    robust=True,
)
ax_native.coastlines()
ax_native.set_title("July 2100 Native Grid")

# Regridded data
sst_future_regridded = sst_ssp585_regridded.sel(time="2100-07").squeeze()
sst_future_regridded.plot(
    ax=ax_regridded,
    x="lon",
    y="lat",
    transform=ccrs.PlateCarree(),
    vmin=-2,
    vmax=30,
    cmap="magma",
    robust=True,
)
ax_regridded.coastlines()
ax_regridded.set_title("July 2100 Regridded")

# %% [markdown]
# ### Questions 3.3
#
# 1. Is this what you expected to see after regridding the data?

# %% [markdown]
# [*Click for solution*](https://github.com/neuromatch/climate-course-content/tree/main/tutorials/W1D5_IntroductiontoClimateModeling/solutions/W1D5_Tutorial7_Solution_1a3fae1b.py)

# %%
# @title Submit your feedback
content_review(f"{feedback_prefix}_Questions_3_3")

# %% [markdown]
# # Summary
#
# In this tutorial you have:
#
# *   Loaded and manipulated data from a CMIP6 model under a high-emissions future scenario experiment
# *   Created maps of future projected changes in the Earth system using CMIP6 data
# *   Converted/regridded CMIP6 model data onto a desired grid. This is a critical processing step that allows us to directly compare data from different models and/or observations

# %% [markdown]
# # Resources
#
# This tutorial uses data from the simulations conducted as part of the [CMIP6](https://wcrp-cmip.org/) multi-model ensemble.
#
# For examples on how to access and analyze data, please visit the [Pangeo Cloud CMIP6 Gallery](https://gallery.pangeo.io/repos/pangeo-gallery/cmip6/index.html)
#
# For more information on what CMIP is and how to access the data, please see this [page](https://github.com/neuromatch/climate-course-content/blob/main/tutorials/CMIP/CMIP_resource_bank.md).
